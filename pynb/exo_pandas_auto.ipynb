# %%
import pandas
import matplotlib.pyplot as plt

df = pandas.read_excel("autompg.xlsx",sep = '\t',header = 0)
print(df)
print(df.describe(include = 'all'))
# Out:
#       mpg  cylindres  déplacement  puissance  poids  accélération  \
# 0    18.0          8        307.0      130.0   3504          12.0
# 1    15.0          8        350.0      165.0   3693          11.5
# 2    18.0          8        318.0      150.0   3436          11.0
# 3    16.0          8        304.0      150.0   3433          12.0
# 4    17.0          8        302.0      140.0   3449          10.5
# ..    ...        ...          ...        ...    ...           ...
# 393  27.0          4        140.0       86.0   2790          15.6
# 394  44.0          4         97.0       52.0   2130          24.6
# 395  32.0          4        135.0       84.0   2295          11.6
# 396  28.0          4        120.0       79.0   2625          18.6
# 397  31.0          4        119.0       82.0   2720          19.4
#
#      année de modèle  origine          Nom de la voiture
# 0                 70        1  chevrolet chevelle malibu
# 1                 70        1          buick skylark 320
# ...

# %%
df['cylindres'].plot.kde()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e4d40191703a> in <module>
# ----> 1 print(g.get_group['accélération'].mean())
#
# NameError: name 'g' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3d71fb63a483> in <module>
# ----> 1 data.plot.scatter(x = 'puissance' ,y = 'mpg', c = 'année de modèle')
#
# NameError: name 'data' is not defined

# %%
df['année de modèle'].value_counts().plot.pie()

# %%
df.plot.hexbin(x='accélération',y='année de modèle',gridsize=25)
